# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import os
from sqlalchemy import create_engine
# %matplotlib inline

# %%
import plotly 
plotly_username = os.environ['plotly_username']
plotly_api_key =os.environ['plotly_api_key']
plotly.tools.set_credentials_file(username= plotly_username, api_key= plotly_api_key)

# %%
connection_string = os.environ['psql_ec2']
conn = create_engine(connection_string)

# %%
pd.read_sql_query('''SELECT * FROM intakes LIMIT 5''', conn)
# Out:
#    id animal_id      name       datetime      monthyear  \
# 0   0   A748291  *Madison   5/1/17 14:26   5/1/17 14:26
# 1   1   A730601      None   7/7/16 12:11   7/7/16 12:11
# 2   2   A748238      None   5/1/17 10:53   5/1/17 10:53
# 3   3   A683644     *Zoey  7/13/14 11:02  7/13/14 11:02
# 4   4   A748635      None   5/4/17 17:56   5/4/17 17:56
#
#                                       found_location      intake_type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...            Stray
# 1                       1109 Shady Ln in Austin (TX)            Stray
# 2     Airport Blvd And Oak Springs Dr in Austin (TX)            Stray
# 3                                        Austin (TX)  Owner Surrender
# 4            11003 Harris Branch Pkwy in Austin (TX)            Stray
#
#   intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0           Normal         Dog   Intact Female       10 months
# 1           Normal         Cat     Intact Male        7 months
# ...

# %%
pd.read_sql_query('''SELECT * FROM outcomes LIMIT 5''', conn)
# Out:
#    id animal_id          name        datetime       monthyear date_of_birth  \
# 0   0   A741715      *Pebbles   1/11/17 18:17   1/11/17 18:17        3/7/16
# 1   1   A658751         Benji  11/13/16 13:38  11/13/16 13:38       7/14/11
# 2   2   A721285          None   2/24/16 14:42   2/24/16 14:42       2/24/14
# 3   3   A746650          Rose    4/7/17 11:58    4/7/17 11:58        4/6/16
# 4   4   A750122  Happy Camper   5/24/17 18:36   5/24/17 18:36        4/8/17
#
#       outcome_type outcome_subtype animal_type sex_upon_outcome  \
# 0         Adoption            None         Cat    Spayed Female
# 1  Return to Owner            None         Dog    Neutered Male
# 2       Euthanasia       Suffering       Other          Unknown
# 3  Return to Owner            None         Dog    Intact Female
# 4         Transfer         Partner         Dog      Intact Male
#
#   age_upon_outcome                                    breed       color
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import *
from sklearn.dummy import DummyClassifier

# %%
def to_pickle(filename,objname):
    with open(filename, 'wb') as f:
        pickle.dump(objname, f)

# %%
def from_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# %%
X_df=from_pickle('Data files/predictors.p')
Y_df=from_pickle('Data files/target.p')

# %% [markdown]
# ## K-nearest neighbors
#
# Best results obtained for weights = uniform, neighbors = 7

# %%
knn_scores_uniform = []
for i in range(1,31):
    clf = KNeighborsClassifier(n_neighbors=i,weights='uniform')
    knn_scores_uniform.append(sum(cross_val_score(clf, X_df, Y_df, cv=5))/5)

# %%
knn_scores_distance = []
for i in range(1,31):
    clf = KNeighborsClassifier(n_neighbors=i,weights='distance')
    knn_scores_distance.append(sum(cross_val_score(clf, X_df, Y_df, cv=5))/5)

# %%
plt.plot(range(1,31),knn_scores_uniform, label='uniform');
plt.plot(range(1,31),knn_scores_distance, label = 'distance');
plt.xlabel("No. of neighbours")
plt.ylabel("Accuracy")
plt.title("kNN accuracy for different k's")
plt.legend();

# %% [markdown]
# ## Logistic Regression
#
# Best results obtained for c=1, penalty = l1

# %%
LR_l1_scores = []
l=[0.1,1,10,100,1000,10000]
for i in l:
    clf = LogisticRegression(n_jobs=-1,random_state=4444,penalty='l1',C=i)
    LR_l1_scores.append(np.mean(cross_val_score(clf, X_df,Y_df, cv=10)))

# %%
LR_l2_scores = []
l=[0.1,1,10,100,1000,10000]
for i in l:
    clf = LogisticRegression(n_jobs=-1,random_state=4444,penalty='l2',C=i)
    LR_l2_scores.append(np.mean(cross_val_score(clf, X_df,Y_df, cv=10)))

# %%
plt.plot(range(len(l)),LR_l1_scores, label='L1 penalty');
plt.plot(range(len(l)),LR_l2_scores, label = 'L2 penalty');
plt.xlabel("C")
plt.xticks(range(len(l)), l)
plt.ylabel("Accuracy")
plt.title("Logistic Regression")
plt.legend();

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
clf = GaussianNB()
np.mean(cross_val_score(clf, X_df,Y_df, cv=10))
# Out:
# 0.58147694594148858

# %% [markdown]
# ## Decision Tree
#
# Best results obtained for criterion = gini, max_depth = 4

# %%
DT_gini = []
for i in range(2,12):
    clf = DecisionTreeClassifier(random_state=4444,max_depth=i,criterion='gini')
    DT_gini.append(np.mean(cross_val_score(clf, X_df,Y_df, cv=10)))

# %%
DT_entropy = []
for i in range(2,12):
    clf = DecisionTreeClassifier(random_state=4444,max_depth=i,criterion='entropy')
    DT_entropy.append(np.mean(cross_val_score(clf, X_df,Y_df, cv=10)))

# %%
plt.plot(range(2,12),DT_gini, label='Gini');
plt.plot(range(2,12),DT_entropy, label = 'Entropy');
plt.xlabel("Max depth")
plt.ylabel("Accuracy")
plt.title("Decision Tree")
plt.legend();

# %% [markdown]
# ## Random Forest Classifier
#
# Best results obtained for criterion = gini, max_depth = 8, max_features = 7, max_trees =100

# %%
max_tree=[10,100,500,750]
criteria=['gini','entropy']
max_f= range(1,8)
max_depth = range(2,12)
for i in max_tree:
    for j in criteria:
        for k in max_f:
            for l in max_depth:
                
                clf = RandomForestClassifier(random_state=4444,n_jobs=-1,criterion=j,n_estimators=i,max_depth=l,max_features=k)
                print "no. of trees=",i,"criteria=",j,"max_features=",k,"max_depth=",l,np.mean(cross_val_score(clf, X_df,Y_df, cv=10))
# Out:
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 2 0.564549657739
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 3 0.589986749343
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 4 0.752550451388
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 5 0.685122993524
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 6 0.738560487007
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 7 0.76040435673
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 8 0.754450912855
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 9 0.760895206068
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 10 0.775599138865
# no. of trees= 10 criteria= gini max_features= 1 max_depth= 11 0.766855979825
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 2 0.587760234506
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 3 0.640068799789
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 4 0.738157153933
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 5 0.769001929149
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 6 0.767013572287
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 7 0.773687050689
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 8 0.778381145016
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 9 0.78163656044
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 10 0.784661021394
# no. of trees= 10 criteria= gini max_features= 2 max_depth= 11 0.784898041974
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 2 0.734494614116
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 3 0.774169685504
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 4 0.779970465631
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 5 0.779086519778
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 6 0.782989618739
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 7 0.787675498543
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 8 0.79252819635
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 9 0.790857804713
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 10 0.788155605812
# no. of trees= 10 criteria= gini max_features= 3 max_depth= 11 0.7890304525
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 2 0.626696062021
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 3 0.745851192022
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 4 0.781321122761
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 5 0.787993716522
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 6 0.784736279061
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 7 0.787040705489
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 8 0.788471422623
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 9 0.787119122588
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 10 0.791574300676
# no. of trees= 10 criteria= gini max_features= 4 max_depth= 11 0.791254945301
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 2 0.77424873449
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 3 0.763764854859
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 4 0.794675788578
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 5 0.787122913906
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 6 0.793008303619
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 7 0.794993374671
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 8 0.791176275447
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 9 0.791336269077
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 10 0.791017292834
# no. of trees= 10 criteria= gini max_features= 5 max_depth= 11 0.793163874045
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 2 0.76995506656
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 3 0.730983474276
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 4 0.787760613637
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 5 0.773543612482
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 6 0.79212928648
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 7 0.792129791989
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 8 0.792527438086
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 9 0.790382247026
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 10 0.791574679807
# no. of trees= 10 criteria= gini max_features= 6 max_depth= 11 0.792210357502
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 2 0.779413963299
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 3 0.781719400744
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 4 0.787600620007
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 5 0.791494872558
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 6 0.794276625954
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 7 0.792527817218
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 8 0.79403935262
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 9 0.792528954613
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 10 0.792368076342
# no. of trees= 10 criteria= gini max_features= 7 max_depth= 11 0.792209725616
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 2 0.564549657739
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 3 0.589986749343
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 4 0.749053718557
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 5 0.666697313156
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 6 0.732358269465
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 7 0.759295396139
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 8 0.749362710995
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 9 0.760657427224
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 10 0.767095401573
# no. of trees= 10 criteria= entropy max_features= 1 max_depth= 11 0.760885980527
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 2 0.587760234506
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 3 0.640148227906
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 4 0.736804474767
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 5 0.767807600708
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 6 0.767247433436
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 7 0.762073990103
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 8 0.776471205254
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 9 0.781401688274
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 10 0.78481937212
# no. of trees= 10 criteria= entropy max_features= 2 max_depth= 11 0.776550254239
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 2 0.731631916075
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 3 0.775836791332
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 4 0.781239419852
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 5 0.777738895703
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 6 0.783068162215
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 7 0.780441852868
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 8 0.789825744694
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 9 0.786330022881
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 10 0.789666509327
# no. of trees= 10 criteria= entropy max_features= 3 max_depth= 11 0.787042853902
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 2 0.626378349551
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 3 0.746876680423
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 4 0.779412699526
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 5 0.785849283725
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 6 0.78298633293
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 7 0.788475593073
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 8 0.782746658427
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 9 0.787123040283
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 10 0.788077188712
# no. of trees= 10 criteria= entropy max_features= 4 max_depth= 11 0.788712360898
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 2 0.772341701405
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 3 0.757405929495
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 4 0.792529712877
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 5 0.784895008919
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 6 0.788474708432
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 7 0.789350060629
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 8 0.789507653092
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 9 0.791177665597
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 10 0.789110512504
# no. of trees= 10 criteria= entropy max_features= 5 max_depth= 11 0.788869826983
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 2 0.769876775838
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 3 0.733766744199
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 4 0.785455428947
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 5 0.785535615328
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 6 0.785213353276
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 7 0.789270506135
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 8 0.788635713081
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 9 0.78704247477
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 10 0.788155479434
# no. of trees= 10 criteria= entropy max_features= 6 max_depth= 11 0.790859447618
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 2 0.779734076937
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 3 0.782037997855
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 4 0.785216891839
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 5 0.788237687852
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 6 0.789430499765
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 7 0.790065292819
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 8 0.789031337141
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 9 0.790698822101
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 10 0.790459273975
# no. of trees= 10 criteria= entropy max_features= 7 max_depth= 11 0.790299280345
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 2 0.762802239153
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 3 0.77544306293
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 4 0.779655912592
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 5 0.786409324621
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 6 0.787442142904
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 7 0.79038439544
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 8 0.791258736619
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 9 0.793164885063
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 10 0.791734420683
# no. of trees= 100 criteria= gini max_features= 1 max_depth= 11 0.79165524532
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 2 0.777030993395
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 3 0.778619808501
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 4 0.786728427241
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 5 0.790144468182
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 6 0.79221187403
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 7 0.793245450576
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 8 0.794436745962
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 9 0.794832875532
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 10 0.795390768014
# no. of trees= 100 criteria= gini max_features= 2 max_depth= 11 0.793561772896
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 2 0.775838055104
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 3 0.786967090726
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 4 0.788794442938
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 5 0.791415823572
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 6 0.791812585028
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 7 0.793323488544
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 8 0.794435355812
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 9 0.796264098175
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 10 0.795548234099
# no. of trees= 100 criteria= gini max_features= 3 max_depth= 11 0.793480575497
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 2 0.780370512896
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 3 0.791335763568
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 4 0.791813090537
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 5 0.792527185332
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 6 0.793800310003
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 7 0.794911924517
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 8 0.794514910307
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 9 0.795468300472
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 10 0.795627156707
# no. of trees= 100 criteria= gini max_features= 4 max_depth= 11 0.795707848597
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 2 0.786013321429
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 3 0.790541735147
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 4 0.79181296416
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 5 0.794435608567
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 6 0.794673640165
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 7 0.794672881901
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 8 0.795070780752
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 9 0.795230268874
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 10 0.795627914971
# no. of trees= 100 criteria= gini max_features= 5 max_depth= 11 0.794673892919
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 2 0.788873365547
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 3 0.788316863215
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 4 0.791494746181
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 5 0.793878979857
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 6 0.794992616408
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 7 0.795310202501
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 8 0.795071286262
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 9 0.795389756995
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 10 0.795310202501
# no. of trees= 100 criteria= gini max_features= 6 max_depth= 11 0.792606234317
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 2 0.788635333949
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 3 0.78839641771
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 4 0.791574806185
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 5 0.793958913484
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 6 0.795389125109
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 7 0.795150082493
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 8 0.795706837579
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 9 0.793720755509
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 10 0.793957649711
# no. of trees= 100 criteria= gini max_features= 7 max_depth= 11 0.792924199542
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 2 0.759464488933
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 3 0.77250055764
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 4 0.775362623794
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 5 0.782595132074
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 6 0.784024079926
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 7 0.78823730872
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 8 0.790384900949
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 9 0.791497400104
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 10 0.790304082681
# no. of trees= 100 criteria= entropy max_features= 1 max_depth= 11 0.790223390791
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 2 0.771863995304
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 3 0.775918115108
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 4 0.784742597925
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 5 0.786965068689
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 6 0.789589482378
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 7 0.791973968809
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 8 0.793166654345
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 9 0.792608509108
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 10 0.793324373185
# no. of trees= 100 criteria= entropy max_features= 2 max_depth= 11 0.792370098378
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 2 0.77059188165
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 3 0.784899937633
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 4 0.78784168466
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 5 0.789271390776
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 6 0.790303577172
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 7 0.791815238951
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 8 0.79268730534
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 9 0.794039984506
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 10 0.793561520142
# no. of trees= 100 criteria= entropy max_features= 3 max_depth= 11 0.794436114076
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 2 0.779734076937
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 3 0.789906942093
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 4 0.789111902654
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 5 0.790383131667
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 6 0.793166148836
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 7 0.792529080991
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 8 0.791734041552
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 9 0.795073308298
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 10 0.794276878709
# no. of trees= 100 criteria= entropy max_features= 4 max_depth= 11 0.795072676412
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 2 0.783153656442
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 3 0.786330781144
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 4 0.787760992769
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 5 0.790145352823
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 6 0.791733788797
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 7 0.7925295865
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 8 0.794118527983
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 9 0.795072423657
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 10 0.79539000975
# no. of trees= 100 criteria= entropy max_features= 5 max_depth= 11 0.794593959293
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 2 0.785378907506
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 3 0.786331792162
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 4 0.787443153922
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 5 0.790224401809
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 6 0.792370856642
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 7 0.793164632308
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 8 0.794913567422
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 9 0.794594591179
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 10 0.794832875532
# no. of trees= 100 criteria= entropy max_features= 6 max_depth= 11 0.793877589707
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 2 0.783947179354
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 3 0.785138095608
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 4 0.787761751033
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 5 0.790146111087
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 6 0.789270632512
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 7 0.794038594356
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 8 0.793958787107
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 9 0.794197071459
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 10 0.794673513787
# no. of trees= 100 criteria= entropy max_features= 7 max_depth= 11 0.792684904171
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 2 0.694275930879
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 3 0.765187104716
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 4 0.77615690497
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 5 0.784421599646
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 6 0.787760360883
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 7 0.788635081194
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 8 0.791495883576
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 9 0.79260888824
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 10 0.792607877222
# no. of trees= 500 criteria= gini max_features= 1 max_depth= 11 0.792289406488
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 2 0.775919252504
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 3 0.782912465412
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 4 0.78911114439
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 5 0.791416581836
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 6 0.793006913469
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 7 0.793721387395
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 8 0.794436872339
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 9 0.79499299554
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 10 0.795787655847
# no. of trees= 500 criteria= gini max_features= 2 max_depth= 11 0.795389377864
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 2 0.781880784525
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 3 0.787285182328
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 4 0.790939633999
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 5 0.792687431717
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 6 0.793959292616
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 7 0.793562025651
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 8 0.794912177272
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 9 0.795786897583
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 10 0.795548992362
# no. of trees= 500 criteria= gini max_features= 3 max_depth= 11 0.794276499577
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 2 0.787602515666
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 3 0.789588597737
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 4 0.791256967337
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 5 0.791733915174
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 6 0.794357444222
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 7 0.795628294103
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 8 0.795866578455
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 9 0.795945627441
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 10 0.795627662216
# no. of trees= 500 criteria= gini max_features= 4 max_depth= 11 0.796423586296
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 2 0.788158638866
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 3 0.789509043242
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 4 0.790462180653
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 5 0.793164379554
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 6 0.795230648006
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 7 0.79618454368
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 8 0.796343020783
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 9 0.795708101352
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 10 0.794674145674
# no. of trees= 500 criteria= gini max_features= 5 max_depth= 11 0.795230142497
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 2 0.787761245524
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 3 0.788952793664
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 4 0.790303450795
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 5 0.793879864498
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 6 0.795787276715
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 7 0.795707090334
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 8 0.795866199324
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 9 0.79570772222
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 10 0.794435229435
# no. of trees= 500 criteria= gini max_features= 6 max_depth= 11 0.793878474348
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 2 0.787999529877
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 3 0.788316989592
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 4 0.790859826749
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 5 0.793720123622
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 6 0.794832749154
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 7 0.795627283084
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 8 0.796025055559
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 9 0.795071412639
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 10 0.793879738121
# no. of trees= 500 criteria= gini max_features= 7 max_depth= 11 0.794197324214
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 2 0.701669949316
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 3 0.76272255828
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 4 0.772977126345
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 5 0.781720664517
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 6 0.785535741705
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 7 0.788000414517
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 8 0.790701855155
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 9 0.791735684456
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 10 0.791654992566
# no. of trees= 500 criteria= entropy max_features= 1 max_depth= 11 0.791257472846
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 2 0.770910731516
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 3 0.781164035808
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 4 0.785614790691
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 5 0.788475972205
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 6 0.790702234287
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 7 0.791257851978
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 8 0.792530218386
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 9 0.793643475805
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 10 0.793880749139
# no. of trees= 500 criteria= entropy max_features= 2 max_depth= 11 0.792767112589
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 2 0.779178459246
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 3 0.784185463707
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 4 0.787124556811
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 5 0.789509548751
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 6 0.79125823111
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 7 0.793245956085
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 8 0.793880370007
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 9 0.793245450576
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 10 0.793641706523
# no. of trees= 500 criteria= entropy max_features= 3 max_depth= 11 0.793641580146
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 2 0.784582604294
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 3 0.786330275635
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 4 0.788079337126
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 5 0.789271390776
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 6 0.790939886753
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 7 0.792132319535
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 8 0.793880370007
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 9 0.793880622762
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 10 0.794436114076
# no. of trees= 500 criteria= entropy max_features= 4 max_depth= 11 0.79427776335
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 2 0.784582857049
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 3 0.786330654767
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 4 0.787125188697
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 5 0.789429615124
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 6 0.789987254852
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 7 0.79165524532
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 8 0.793402790284
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 9 0.794356812335
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 10 0.79602543469
# no. of trees= 500 criteria= entropy max_features= 5 max_depth= 11 0.795071665393
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 2 0.784900948651
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 3 0.785536373591
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 4 0.787443027545
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 5 0.78966916325
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 6 0.790622806169
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 7 0.792528828236
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 8 0.794674145674
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 9 0.795231027138
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 10 0.795230268874
# no. of trees= 500 criteria= entropy max_features= 6 max_depth= 11 0.793639937241
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 2 0.785218534744
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 3 0.785615675332
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 4 0.787681691029
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 5 0.789748591367
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 6 0.790542746166
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 7 0.792687937226
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 8 0.794833760173
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 9 0.79443497668
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 10 0.795070780752
# no. of trees= 500 criteria= entropy max_features= 7 max_depth= 11 0.79435567494
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 2 0.739274455425
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 3 0.771626721969
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 4 0.778938531989
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 5 0.784899052992
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 6 0.78855502119
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 7 0.789986370211
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 8 0.791735305324
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 9 0.793086088832
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 10 0.793402916661
# no. of trees= 750 criteria= gini max_features= 1 max_depth= 11 0.792766986212
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 2 0.77671302817
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 3 0.78553599446
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 4 0.790066682969
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 5 0.791575690826
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 6 0.792768376362
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 7 0.794118907115
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 8 0.794357191467
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 9 0.794674903937
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 10 0.795946638459
# no. of trees= 750 criteria= gini max_features= 2 max_depth= 11 0.795230016119
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 2 0.783230936146
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 3 0.787523593058
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 4 0.791179308501
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 5 0.792687558094
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 6 0.793958913484
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 7 0.793879990876
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 8 0.794912556404
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 9 0.795945880196
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 10 0.795866325701
# no. of trees= 750 criteria= gini max_features= 3 max_depth= 11 0.795150967134
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 2 0.787999529877
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 3 0.789191078017
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 4 0.790780272255
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 5 0.791813216915
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 6 0.794435734944
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 7 0.795707090334
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 8 0.795946006573
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 9 0.796263592666
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 10 0.796184417303
# no. of trees= 750 criteria= gini max_features= 4 max_depth= 11 0.796423333542
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 2 0.788793937429
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 3 0.789349807875
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 4 0.790859826749
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 5 0.793084572305
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 6 0.794753700169
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 7 0.796105115563
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 8 0.796184038171
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 9 0.796502635282
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 10 0.795071918148
# no. of trees= 750 criteria= gini max_features= 5 max_depth= 11 0.795627156707
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 2 0.788555526699
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 3 0.788714382935
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 4 0.790779766745
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 5 0.793720881886
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 6 0.795707595843
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 7 0.795468426849
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 8 0.795945627441
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 9 0.795310328878
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 10 0.795229889742
# no. of trees= 750 criteria= gini max_features= 6 max_depth= 11 0.794117137833
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 2 0.788555526699
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 3 0.788237561475
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 4 0.791097984725
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 5 0.794356054072
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 6 0.794832622777
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 7 0.795627788594
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 8 0.795706837579
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 9 0.795071791771
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 10 0.793879485366
# no. of trees= 750 criteria= gini max_features= 7 max_depth= 11 0.79356114101
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 2 0.739987791955
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 3 0.769240466256
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 4 0.77591849424
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 5 0.782197991486
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 6 0.786091612151
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 7 0.78879482207
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 8 0.791099374875
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 9 0.791655624452
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 10 0.792768881871
# no. of trees= 750 criteria= entropy max_features= 1 max_depth= 11 0.791575438071
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 2 0.771388058485
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 3 0.78323169441
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 4 0.786251353027
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 5 0.78847571945
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 6 0.79086071139
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 7 0.791734926193
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 8 0.793165390572
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 9 0.793245450576
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 10 0.793641959277
# no. of trees= 750 criteria= entropy max_features= 2 max_depth= 11 0.793084572305
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 2 0.7810066961
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 3 0.784503934441
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 4 0.786727921732
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 5 0.788794190184
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 6 0.791258483864
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 7 0.79380233204
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 8 0.793562404783
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 9 0.794278142482
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 10 0.79427776335
# no. of trees= 750 criteria= entropy max_features= 3 max_depth= 11 0.793879485366
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 2 0.784186348348
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 3 0.786410209262
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 4 0.787840420887
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 5 0.789509169619
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 6 0.791019694003
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 7 0.792131687648
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 8 0.793642212032
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 9 0.793960177257
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 10 0.794197197837
# no. of trees= 750 criteria= entropy max_features= 4 max_depth= 11 0.795549497871
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 2 0.784900948651
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 3 0.785854212439
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 4 0.787602262911
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 5 0.789589356
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 6 0.790145731955
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 7 0.792291049393
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 8 0.79403935262
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 9 0.794674903937
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 10 0.796104862808
# no. of trees= 750 criteria= entropy max_features= 5 max_depth= 11 0.795071539016
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 2 0.784900822274
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 3 0.785774657944
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 4 0.787522455662
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 5 0.789987254852
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 6 0.790463823557
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 7 0.793005649696
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 8 0.794118275228
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 9 0.795310202501
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 10 0.794673766542
# no. of trees= 750 criteria= entropy max_features= 6 max_depth= 11 0.793560382746
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 2 0.78474146053
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 3 0.785774784321
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 4 0.787046013334
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 5 0.789828145862
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 6 0.790145479201
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 7 0.793005776073
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 8 0.794992363653
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 9 0.79443497668
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 10 0.795150335247
# no. of trees= 750 criteria= entropy max_features= 7 max_depth= 11 0.794036951452

# %% [markdown]
# ## ROC CURVES

# %%
X_train, X_test, y_train, y_test = train_test_split(X_df,Y_df, test_size=0.2, random_state=4444)

# %%
clf = RandomForestClassifier(random_state=4444,n_jobs=-1,criterion='gini',n_estimators=100,max_depth=8,max_features=7)
print "Random Forest"
clf.fit(X_train, y_train)
probs = clf.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, probs[:,1])
print 'AUC:',auc(fpr, tpr)
class_pred = clf.predict(X_test)
print 'F1:',f1_score(y_test, class_pred)
print 'Accuracy:',accuracy_score(y_test, class_pred)
plt.plot(fpr, tpr,label = 'Random Forest');

clf = DecisionTreeClassifier(random_state=4444,max_depth=4,criterion='gini')
print "\nDecision Tree"
clf.fit(X_train, y_train)
probs = clf.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, probs[:,1])
print 'AUC:',auc(fpr, tpr) 
class_pred = clf.predict(X_test)
print 'F1:',f1_score(y_test, class_pred)
print 'Accuracy:',accuracy_score(y_test, class_pred)
plt.plot(fpr, tpr,label = 'Decision Tree');

clf = KNeighborsClassifier(n_neighbors=7,n_jobs=-1)
print "\nkNN"
clf.fit(X_train, y_train)
probs = clf.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, probs[:,1])
print 'AUC:',auc(fpr, tpr)
class_pred = clf.predict(X_test)
print 'F1:',f1_score(y_test, class_pred)
print 'Accuracy:',accuracy_score(y_test, class_pred)
plt.plot(fpr, tpr,label = 'kNN');

clf = LogisticRegression(n_jobs=-1,random_state=4444,penalty='l1',C=1)
print "\nLogistic Regression"
clf.fit(X_train, y_train)
probs = clf.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, probs[:,1])
print 'AUC:',auc(fpr, tpr)
class_pred = clf.predict(X_test)
print 'F1:',f1_score(y_test, class_pred)
print 'Accuracy:',accuracy_score(y_test, class_pred)
plt.plot(fpr, tpr,label = 'Logisitic Regression');

clf = GaussianNB()
print "\nNaive Bayes"
clf.fit(X_train, y_train)
probs = clf.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, probs[:,1])
print('AUC:',auc(fpr, tpr))
class_pred = clf.predict(X_test)
print 'F1:',f1_score(y_test, class_pred)
print 'Accuracy:',accuracy_score(y_test, class_pred)
plt.plot(fpr, tpr,label = 'Naive Bayes');

clf = DummyClassifier(random_state=4444)
print "\nDummy Classifier"
clf.fit(X_train, y_train)
probs = clf.predict_proba(X_test)
fpr, tpr, threshold = roc_curve(y_test, probs[:,1])
print('AUC:',auc(fpr, tpr))
class_pred = clf.predict(X_test)
print 'F1:',f1_score(y_test, class_pred)
print 'Accuracy:',accuracy_score(y_test, class_pred)
plt.plot(fpr, tpr,label = 'Dummy Classifier');

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# Random Forest
# AUC: 0.900120997251
# F1: 0.848016139879
# Accuracy: 0.820349761526
#
# Decision Tree
# AUC: 0.878538915272
# F1: 0.81981032666
# Accuracy: 0.796104928458
#
# kNN
# AUC: 0.804364675415
# F1: 0.763347763348
# Accuracy: 0.739268680445
#
# Logistic Regression
# AUC: 0.711968681868
# F1: 0.700261291527
# Accuracy: 0.680842607313
#
# Naive Bayes
# ('AUC:', 0.69441295350920651)
# F1: 0.710526315789
# Accuracy: 0.580286168521
#
# Dummy Classifier
# ('AUC:', 0.49626389990100228)
# F1: 0.53730246233
# Accuracy: 0.49960254372

# %% [markdown]
# ## Best Model: random forest

# %%
clf = RandomForestClassifier(random_state=4444,n_jobs=-1,criterion='gini',n_estimators=100,max_depth=8,max_features=7)
print np.mean(cross_val_score(clf, X_df,Y_df, cv=10))
clf.fit(X_train, y_train);
# Out:
# 0.795706837579

# %%
clf.feature_importances_
# Out:
# array([ 0.04206565,  0.75570971,  0.03021559,  0.00086489,  0.00333571,
#         0.00562361,  0.00235289,  0.00257006,  0.00228171,  0.00301967,
#         0.00271751,  0.00195658,  0.00179678,  0.00345896,  0.00107012,
#         0.00454665,  0.00314171,  0.00223657,  0.00251164,  0.03454041,
#         0.02439747,  0.00450066,  0.01771266,  0.01351626,  0.00504828,
#         0.02880826])

# %%
importances = clf.feature_importances_
importances
imp_dic={}
for ind, imp in enumerate(importances):
    name = X_df.columns[ind]
    imp_dic[name]=imp

# %%
import operator
sorted_x = sorted(imp_dic.items(), key=operator.itemgetter(1),reverse=True)
sorted_x
# Out:
# [('IntakeAge', 0.75570970772735746),
#  ('Name', 0.042065652065268563),
#  ('Intake Type_Owner Surrender', 0.034540406329112726),
#  ('adoption_month', 0.03021558722234137),
#  ('neutered', 0.028808259425315338),
#  ('Intake Type_Stray', 0.024397469005611256),
#  ('Intake Condition_Normal', 0.017712662311165375),
#  ('Intake Condition_Nursing', 0.013516258464019376),
#  ('black', 0.005623611875217609),
#  ('Male', 0.0050482770376355001),
#  ('Domestic_short', 0.0045466478004663104),
#  ('Intake Condition_Injured', 0.0045006629966426624),
#  ('Point', 0.0034589578507338643),
#  ('white', 0.0033357140588573847),
#  ('Domestic_med', 0.0031417083192852645),
#  ('mix_color', 0.0030196727851549057),
#  ('Tabby', 0.0027175102680414109),
#  ('brown', 0.0025700600030075403),
#  ('Siamese', 0.0025116425086010212),
#  ('blue', 0.002352891343333983),
#  ('orange', 0.0022817080512716318),
#  ('Domestic_long', 0.0022365675671290053),
#  ('Calico', 0.0019565768387691728),
#  ('Tortie', 0.001796778865069802),
#  ('Torbie', 0.0010701223367545853),
#  ('Smoke', 0.00086488694383662424)]

# %% [markdown]
# <img src="images/variable importance.png">
